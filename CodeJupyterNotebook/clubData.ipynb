# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
# import constant
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

import csv


Options = webdriver.ChromeOptions()
Options.add_argument('--headless')
driver = webdriver.Chrome(
    executable_path='/usr/local/bin/chromedriver.exe', chrome_options=Options)

attribute_dict = dict()
data = dict()
# retrieved data
dataList = dict()
# retrieved data
teamList = dict()
final = dict()
final_arr = dict()
teams = ['Leicester City', 'Southampton', 'Wolverhampton Wanderers', 'Liverpool', 'Arsenal', 'Tottenham Hotspur', 'Watford', 'AFC Bournemouth', 'Manchester United', 'Everton',
         'Aston Villa', 'Norwich City', 'Burnley', 'Newcastle United', 'Crystal Palace', 'West Ham United', 'Sheffield United', 'Chelsea', 'Manchester City', 'Brighton and Hove Albion']

for i in teams:
    final[i] = dict()
    final_arr[i] = []


# get all attributes
attribute_url = 'https://www.premierleague.com/stats/top/clubs/losses?se=274'
page = requests.get(attribute_url)
mySoup = BeautifulSoup(page.content, 'html.parser')
attribute = mySoup.body.find_all(attrs={"role": "option"})

for i in range(len(attribute)):
    attribute_dict[attribute[i].text.strip()] = attribute[i].text.strip()

attribute_display = attribute_dict

attribute_dict['Own goals'] = "own_goals"
attribute_dict['Yellow cards'] = "total_yel_card"
attribute_dict['Red cards'] = "total_red_card"
attribute_dict['Passes'] = "total_pass"
attribute_dict['Shots'] = "total_scoring_att"
attribute_dict['Offsides'] = "total_offside"
attribute_dict['Hit woodwork'] = 'hit_woodwork'
attribute_dict['Big chances missed'] = 'big_chance_missed'
attribute_dict['Tackles'] = 'total_tackle'
attribute_dict['Clearances'] = 'total_clearance'
attribute_dict['Clearances off line'] = 'clearance_off_line'
attribute_dict['Dispossessed'] = 'dispossessed'
attribute_dict['Clean sheets'] = 'clean_sheet'
attribute_dict['Penalties Saved'] = 'penalty_save'
attribute_dict['High claims'] = 'total_high_claim'
# attribute_dict['punches'] = 'punches'

print(attribute_dict)
# test variables
test = ['Own goals']
for i in attribute_dict:
    for j in teams:
        final[j][i] = 0
# scraping
for att in attribute_dict:
    # here is the url we're gonna scraping
    scrape_url = 'https://www.premierleague.com/stats/top/clubs/' + \
        attribute_dict[att] + '?se=274'

    # html_page
    # page = requests.get(scrape_url)
    driver.get(scrape_url)
    time.sleep(4)
    # print(page.status_code)
    # parse html_page into BeautifulSoup
    # mySoup = BeautifulSoup(page.content, 'html.parser')
    content = driver.page_source
    mySoup = BeautifulSoup(content, 'html.parser')
    # print(mySoup)
    data = mySoup.find_all("td", class_="mainStat text-centre")
    # print(data)
    # list data of that attribute
    dataList[att] = []
    teamList[att] = []

    team = mySoup.find_all("a", class_="playerName")
    # print(i)
    # print(len(data))
    for dt in range(len(data)):
        dataTemp = data[dt].text
        dataList[att].append(dataTemp)
        teamTemp = team[dt].text.strip()
        teamList[att].append(teamTemp)
 
        final[teamTemp][att] = dataTemp
        final_arr[teamTemp].append(dataTemp)
        
    # print(teamList[att])

# print(final)
# first character of team name should be in upper-case
# print(final['Liverpool'])
# csv_columns = dict()

# for i in attribute_dict:
#     csv_columns[i] = 'i'

# csv_file = "Clubs.csv"
# try:
#     with open(csv_file, 'w') as csvfile:
#         writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
#         writer.writeheader()
#         for team in teams:
#             writer.writerow(final[team])
# except IOError:
#     print("I/O error")

# for team in teams:
#     df = pd.DataFrame(final_arr[team])
# Out:
# {'Wins': 'Wins', 'Losses': 'Losses', 'Touches': 'Touches', 'Own goals': 'own_goals', 'Yellow cards': 'total_yel_card', 'Red cards': 'total_red_card', 'Goals': 'Goals', 'Passes': 'total_pass', 'Shots': 'total_scoring_att', 'Offsides': 'total_offside', 'Hit woodwork': 'hit_woodwork', 'Big chances missed': 'big_chance_missed', 'Tackles': 'total_tackle', 'Clearances': 'total_clearance', 'Clearances off line': 'clearance_off_line', 'Dispossessed': 'dispossessed', 'Clean sheets': 'clean_sheet', 'Saves': 'Saves', 'Penalties Saved': 'penalty_save', 'High claims': 'total_high_claim', 'Punches': 'Punches'}
# ['Liverpool', 'Manchester City', 'Chelsea', 'Leicester City', 'Manchester United', 'Tottenham Hotspur', 'Burnley', 'Southampton', 'Wolverhampton Wanderers', 'Arsenal', 'Sheffield United', 'Everton', 'Crystal Palace', 'Newcastle United', 'West Ham United', 'Aston Villa', 'AFC Bournemouth', 'Brighton and Hove Albion', 'Watford', 'Norwich City']
# ['Norwich City', 'AFC Bournemouth', 'Aston Villa', 'Watford', 'West Ham United', 'Crystal Palace', 'Newcastle United', 'Southampton', 'Brighton and Hove Albion', 'Everton', 'Burnley', 'Chelsea', 'Leicester City', 'Sheffield United', 'Tottenham Hotspur', 'Arsenal', 'Manchester City', 'Wolverhampton Wanderers', 'Manchester United', 'Liverpool']
# ['Manchester City', 'Liverpool', 'Chelsea', 'Leicester City', 'Manchester United', 'Tottenham Hotspur', 'Arsenal', 'Brighton and Hove Albion', 'Norwich City', 'Wolverhampton Wanderers', 'Southampton', 'Everton', 'Crystal Palace', 'West Ham United', 'AFC Bournemouth', 'Sheffield United', 'Aston Villa', 'Watford', 'Newcastle United', 'Burnley']
# ['Brighton and Hove Albion', 'Chelsea', 'Everton', 'Leicester City', 'Norwich City', 'Watford', 'West Ham United', 'Crystal Palace', 'Newcastle United', 'Tottenham Hotspur', 'Aston Villa', 'Burnley', 'Liverpool', 'Manchester City', 'Manchester United', 'Southampton', 'Wolverhampton Wanderers']
# ['Arsenal', 'Tottenham Hotspur', 'Watford', 'AFC Bournemouth', 'Manchester United', 'Everton', 'Aston Villa', 'Norwich City', 'Burnley', 'Newcastle United', 'Crystal Palace', 'West Ham United', 'Sheffield United', 'Chelsea', 'Manchester City', 'Brighton and Hove Albion', 'Wolverhampton Wanderers', 'Southampton', 'Leicester City', 'Liverpool']
# ['Arsenal', 'Manchester City', 'Southampton', 'AFC Bournemouth', 'Crystal Palace', 'Everton', 'Leicester City', 'Newcastle United', 'Norwich City', 'Sheffield United', 'Tottenham Hotspur', 'Watford', 'Brighton and Hove Albion', 'West Ham United', 'Wolverhampton Wanderers', 'Aston Villa', 'Liverpool']
# ['Manchester City', 'Liverpool', 'Chelsea', 'Leicester City', 'Manchester United', 'Tottenham Hotspur', 'Arsenal', 'Wolverhampton Wanderers', 'Southampton', 'West Ham United', 'Everton', 'Burnley', 'Aston Villa', 'AFC Bournemouth', 'Brighton and Hove Albion', 'Sheffield United', 'Newcastle United', 'Watford', 'Crystal Palace', 'Norwich City']
# ['Manchester City', 'Burnley', 'Liverpool', 'Leicester City', 'Manchester United', 'Sheffield United', 'Wolverhampton Wanderers', 'Newcastle United', 'Arsenal', 'Crystal Palace', 'Brighton and Hove Albion', 'Chelsea', 'Everton', 'Southampton', 'Watford', 'Tottenham Hotspur', 'Aston Villa', 'West Ham United', 'AFC Bournemouth', 'Norwich City']
# ['Arsenal', 'Newcastle United', 'Norwich City', 'Tottenham Hotspur', 'AFC Bournemouth', 'West Ham United', 'Crystal Palace', 'Burnley', 'Brighton and Hove Albion', 'Watford', 'Aston Villa', 'Southampton', 'Sheffield United', 'Leicester City', 'Manchester United', 'Everton', 'Wolverhampton Wanderers', 'Liverpool', 'Manchester City', 'Chelsea']
# ['Norwich City', 'Leicester City', 'Tottenham Hotspur', 'Wolverhampton Wanderers', 'Arsenal', 'Aston Villa', 'AFC Bournemouth', 'Brighton and Hove Albion', 'Burnley', 'Sheffield United', 'Southampton', 'Watford', 'West Ham United']
# ['Burnley', 'Norwich City', 'Watford', 'Southampton', 'Arsenal', 'Everton', 'Tottenham Hotspur', 'Aston Villa', 'Crystal Palace', 'Brighton and Hove Albion', 'Chelsea', 'Newcastle United', 'Sheffield United', 'Wolverhampton Wanderers', 'AFC Bournemouth', 'Liverpool', 'Manchester City', 'Leicester City', 'Manchester United', 'West Ham United']
# ['Crystal Palace', 'West Ham United', 'Norwich City', 'Newcastle United', 'Arsenal', 'AFC Bournemouth', 'Sheffield United', 'Southampton', 'Liverpool', 'Tottenham Hotspur', 'Watford', 'Brighton and Hove Albion', 'Burnley', 'Everton', 'Aston Villa', 'Manchester City', 'Manchester United', 'Leicester City', 'Chelsea', 'Wolverhampton Wanderers']
# {'Leicester City': {'Wins': '18', 'Losses': '12', 'Touches': '27,659', 'Own goals': '3', 'Yellow cards': '41', 'Red cards': '3', 'Goals': '67', 'Passes': '19,915', 'Shots': '540', 'Offsides': '64', 'Hit woodwork': '12', 'Big chances missed': '49', 'Tackles': '742', 'Clearances': '700', 'Clearances off line': '1', 'Dispossessed': '328', 'Clean sheets': '13', 'Saves': '96', 'Penalties Saved': '2', 'High claims': '14', 'Punches': '8'}, 'Southampton': {'Wins': '15', 'Losses': '16', 'Touches': '23,611', 'Own goals': '1', 'Yellow cards': '53', 'Red cards': '4', 'Goals': '51', 'Passes': '15,667', 'Shots': '499', 'Offsides': '58', 'Hit woodwork': '16', 'Big chances missed': '46', 'Tackles': '706', 'Clearances': '824', 'Clearances off line': '1', 'Dispossessed': '362', 'Clean sheets': '9', 'Saves': '109', 'Penalties Saved': '1', 'High claims': '29', 'Punches': '16'}, 'Wolverhampton Wanderers': {'Wins': '15', 'Losses': '9', 'Touches': '24,066', 'Own goals': '1', 'Yellow cards': '57', 'Red cards': '2', 'Goals': '52', 'Passes': '16,764', 'Shots': '461', 'Offsides': '49', 'Hit woodwork': '10', 'Big chances missed': '47', 'Tackles': '646', 'Clearances': '652', 'Clearances off line': '1', 'Dispossessed': '338', 'Clean sheets': '13', 'Saves': '91', 'Penalties Saved': '2', 'High claims': '21', 'Punches': '5'}, 'Liverpool': {'Wins': '32', 'Losses': '3', 'Touches': '30,987', 'Own goals': '1', 'Yellow cards': '38', 'Red cards': '1', 'Goals': '85', 'Passes': '23,872', 'Shots': '591', 'Offsides': '53', 'Hit woodwork': '17', 'Big chances missed': '65', 'Tackles': '550', 'Clearances': '587', 'Clearances off line': '2', 'Dispossessed': '306', 'Clean sheets': '15', 'Saves': '76', 'Penalties Saved': 0, 'High claims': '18', 'Punches': '14'}, 'Arsenal': {'Wins': '14', 'Losses': '10', 'Touches': '25,916', 'Own goals': 0, 'Yellow cards': '86', 'Red cards': '5', 'Goals': '56', 'Passes': '18,649', 'Shots': '406', 'Offsides': '73', 'Hit woodwork': '15', 'Big chances missed': '31', 'Tackles': '584', 'Clearances': '703', 'Clearances off line': '6', 'Dispossessed': '370', 'Clean sheets': '10', 'Saves': '147', 'Penalties Saved': '1', 'High claims': '25', 'Punches': '18'}, 'Tottenham Hotspur': {'Wins': '16', 'Losses': '11', 'Touches': '26,302', 'Own goals': '2', 'Yellow cards': '82', 'Red cards': '3', 'Goals': '61', 'Passes': '18,644', 'Shots': '444', 'Offsides': '66', 'Hit woodwork': '7', 'Big chances missed': '35', 'Tackles': '665', 'Clearances': '841', 'Clearances off line': '4', 'Dispossessed': '437', 'Clean sheets': '8', 'Saves': '140', 'Penalties Saved': '2', 'High claims': '24', 'Punches': '13'}, 'Watford': {'Wins': '8', 'Losses': '20', 'Touches': '21,331', 'Own goals': '3', 'Yellow cards': '76', 'Red cards': '3', 'Goals': '36', 'Passes': '14,067', 'Shots': '424', 'Offsides': '68', 'Hit woodwork': '9', 'Big chances missed': '41', 'Tackles': '657', 'Clearances': '822', 'Clearances off line': '5', 'Dispossessed': '348', 'Clean sheets': '9', 'Saves': '117', 'Penalties Saved': '1', 'High claims': '30', 'Punches': '13'}, 'AFC Bournemouth': {'Wins': '9', 'Losses': '22', 'Touches': '22,199', 'Own goals': 0, 'Yellow cards': '74', 'Red cards': '3', 'Goals': '40', 'Passes': '14,694', 'Shots': '389', 'Offsides': '67', 'Hit woodwork': '11', 'Big chances missed': '36', 'Tackles': '507', 'Clearances': '926', 'Clearances off line': '4', 'Dispossessed': '384', 'Clean sheets': '5', 'Saves': '131', 'Penalties Saved': '1', 'High claims': '20', 'Punches': '18'}, 'Manchester United': {'Wins': '18', 'Losses': '8', 'Touches': '27,360', 'Own goals': '1', 'Yellow cards': '73', 'Red cards': 0, 'Goals': '66', 'Passes': '20,059', 'Shots': '544', 'Offsides': '56', 'Hit woodwork': '15', 'Big chances missed': '52', 'Tackles': '580', 'Clearances': '627', 'Clearances off line': 0, 'Dispossessed': '396', 'Clean sheets': '13', 'Saves': '96', 'Penalties Saved': 0, 'High claims': '13', 'Punches': '10'}, 'Everton': {'Wins': '13', 'Losses': '15', 'Touches': '23,388', 'Own goals': '3', 'Yellow car ...
# {'Wins': '32', 'Losses': '3', 'Touches': '30,987', 'Own goals': '1', 'Yellow cards': '38', 'Red cards': '1', 'Goals': '85', 'Passes': '23,872', 'Shots': '591', 'Offsides': '53', 'Hit woodwork': '17', 'Big chances missed': '65', 'Tackles': '550', 'Clearances': '587', 'Clearances off line': '2', 'Dispossessed': '306', 'Clean sheets': '15', 'Saves': '76', 'Penalties Saved': 0, 'High claims': '18', 'Punches': '14'}

# %%
print(final['Liverpool']['Losses'])
# Out:
# 3

# %%
import panda as pd
pf = pd.read
